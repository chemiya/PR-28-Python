# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing the dataset
dataset = pd.read_csv('./../../datasets/salary_data.csv')

print(dataset)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X= dataset.iloc[:, 0].values
print(X)#cojo col de años de experiencia
# Out:
# [ 1.1  1.3  1.5  2.   2.2  2.9  3.   3.2  3.2  3.7  3.9  4.   4.   4.1
#   4.5  4.9  5.1  5.3  5.9  6.   6.8  7.1  7.9  8.2  8.7  9.   9.5  9.6
#  10.3 10.5]

# %%
y= dataset.iloc[:, 1].values
print(y)#cojo salarios
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %%
# entreno el modelo
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 1/3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()#creo regresion lineal

# %%
print("shape x_train:",X_train.shape)
print(X_train)
X_train = X_train.reshape(-1,1)
# filas desconocidas, 1 columnas. reshape(-1,1) cuando son todos de una caracteristica
#reshape(1,-1) cuando son todos de una muestra
#transforma a una forma compatible con la original
print("shape x_train:",X_train.shape)
print(X_train)
# Out:
# shape x_train: (20,)
# [ 2.9  5.1  3.2  4.5  8.2  6.8  1.3 10.5  3.   2.2  5.9  6.   3.7  3.2
#   9.   2.   1.1  7.1  4.9  4. ]
# shape x_train: (20, 1)
# [[ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]

# %%
print("shape y_train:",y_train.shape)
print(y_train)
y_train = y_train.reshape(-1,1)
print("shape y_train:",y_train.shape)
print(y_train)
# Out:
# shape y_train: (20,)
# [ 56642.  66029.  64445.  61111. 113812.  91738.  46205. 121872.  60150.
#   39891.  81363.  93940.  57189.  54445. 105582.  43525.  39343.  98273.
#   67938.  56957.]
# shape y_train: (20, 1)
# [[ 56642.]
#  [ 66029.]
#  [ 64445.]
#  [ 61111.]
#  [113812.]
#  [ 91738.]
#  [ 46205.]
#  [121872.]
#  [ 60150.]
#  [ 39891.]
#  [ 81363.]
#  [ 93940.]
#  [ 57189.]
#  [ 54445.]
#  [105582.]
#  [ 43525.]
#  [ 39343.]
#  [ 98273.]
#  [ 67938.]
#  [ 56957.]]

# %%
regressor.fit(X_train,y_train)#entreno
# Out:
# LinearRegression()

# %%
print(X_test.shape)
print(X_test)
print("nuevo")
X_test=(X_test.reshape(-1,1))
print(X_test)
# Out:
# (10,)
# [ 1.5 10.3  4.1  3.9  9.5  8.7  9.6  4.   5.3  7.9]
# nuevo
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]
#  [ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]]

# %%
#predccion
y_pred = regressor.predict(X_test)


#grafico con los puntos
plt.scatter(X_train, y_train, color = 'blue')

#la recta
plt.plot(X_train, regressor.predict(X_train), color ='green')
plt.title('Salary vs experience(Training set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %%
#los puntos
plt.scatter(X_test, y_test, color = 'red')

# la recta
plt.plot(X_test, regressor.predict(X_test), color ='black')
plt.title('Salary vs experience(Test set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()
