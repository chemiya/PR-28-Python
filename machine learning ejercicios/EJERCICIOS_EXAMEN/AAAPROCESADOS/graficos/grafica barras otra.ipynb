# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
valores=[2,3,4]
etiquetas=["chema","juan","federico"]

# %%
plt.bar(etiquetas, valores)
plt.xlabel("grafico")
plt.ylabel("numeros")
plt.title("titulo")
plt.show()
