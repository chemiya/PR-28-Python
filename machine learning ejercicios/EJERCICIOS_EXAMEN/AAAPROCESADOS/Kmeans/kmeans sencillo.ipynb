# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs

# %%
X, y = make_blobs(n_samples=200, centers=5)
print(X.shape,y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X, y = make_blobs(n_samples=200, centers=5)
#       2 print(X.shape,y.shape)
#
# NameError: name 'make_blobs' is not defined

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
k_means = KMeans( n_clusters = 5)

# %%
k_means.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
print(k_means.cluster_centers_)
z=k_means.cluster_centers_
# Out:
# [[  6.82758686 -10.06209736]
#  [ -6.96589206  -0.09161137]
#  [  6.45135284   2.48007087]
#  [ -5.97791643  -2.3011662 ]
#  [  4.1988025   -8.65643086]]

# %%
print(k_means.labels_)
# Out:
# [2 4 4 4 3 0 1 2 2 4 4 2 3 0 3 0 2 0 2 0 2 4 0 3 1 4 4 2 2 2 2 3 3 4 2 2 0
#  4 1 4 3 4 0 3 0 1 1 3 2 1 1 4 2 1 1 4 1 0 0 3 3 3 2 1 3 1 0 1 1 4 2 1 4 3
#  2 3 1 0 2 1 4 1 4 3 1 1 0 0 0 3 1 4 0 3 2 0 3 2 0 3 0 2 4 2 0 0 2 2 4 1 1
#  1 0 0 3 1 4 4 2 1 3 0 2 0 1 4 1 4 1 4 0 0 2 3 1 4 1 2 1 4 0 1 4 2 0 4 0 1
#  4 4 3 4 1 0 4 3 3 2 4 2 2 2 3 4 1 3 4 1 0 4 0 1 1 1 2 3 2 4 1 4 0 2 4 1 1
#  4 4 1 1 2 1 3 2 3 3 3 2 0 0 3]

# %%
plt.scatter(X[:,0],X[:,1],c=k_means.labels_)
plt.scatter(z[:,0],z[:,1],c="black",marker="*")
plt.show()
